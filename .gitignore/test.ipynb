# %%
import pandas as pd
from pymongo import MongoClient

# %%
client =  MongoClient("mongodb+srv://prosowiec:ATLASSTOCKDATA@stockdata.olon5zx.mongodb.net/?retryWrites=true&w=majority")
db = client['stockdata']
collection = db['stonks']

# %%
symbols_filename = 'recent_symbols.csv'

symbols_df = pd.read_csv(symbols_filename)
symbols_df.head()

for i in symbols_df.index:
            if symbols_df['scraped'][i] == 0:
                print(str(symbols_df['symbols'][i]))
                
                
                symbols_df.loc[i, 'scraped'] = 1
# Out:
# WCC
# LUNMF
# AMC
# VLY
# AYI
# MPC
# TEX
# ATAT
# RIG
# PKX
# JCI
# CARR
# ALSMY
# LUMN
# GOCO
# AGCO
# TAL
# RLLCF
# BBIO
# WING
# NIO
# PLUG
# KMT
# LIFW
# CMA
# TFC
# ONB
# WOLF
# BHPLF
# LPL
# ATKR
# NVT
# MPNGF
# WFRD
# MGPI
# BLD
# NUE
# ALLE
# WAL
# ZION
# PR
# LKNCY
# SFNC
# HRI
# CVI
# URI
# WSC
# KEY
# CMC
# AWI
# FRC
# TGS
# FLR
# MGRC
# CNICF
# DINO
# AMBP
# VLO
# ABCB
# MLI
# PILBF
# BHF
# AI
# STLD
# OLK
# ETRN
# CAT
# MEOH
# MTZ
# MRTX
# PBF
# TT
# DOOO
# CRS
# MYRG
# NE
# CLF
# DISH
# HUBB
# X
# NEO
# RRX
# XPEV
# TKGBY
# MTSI
# GBCI
# LNC
# GTLS
# BE
# WIRE
# GNRC
# XRX
# WD
# VAL
# DADA
# OSK
# AXSM
# VRT
# TDW
# CALM
# AVAV
# HLN
# WWE
# NTDOY
# FNLPF
# SNOW
# AGI
# ONON
# AU
# AEM
# SQSP
# SBSW
# DRS
# GRAB
# BTG
# KGC
# FSLY
# CR
# LZRFY
# S
# CLLNY
# TEAM
# HMY
# SONO
# NTDOF
# NEM
# SWAV
# BBSEY
# NARI
# RPD
# ZIM
# FIVN
# GFI
# AG
# LSI
# HCM
# BUR
# APE
# EXR
# OLYMY
# GOLD
# GETY
# CXMSF
# TKC
# ZIJMF
# NPNYY
# PSLV
# HL
# EHC

# %%
symbols_df.head()
# Out:
#   symbols  scraped
# 0     WCC        1
# 1   LUNMF        1
# 2     AMC        1
# 3     VLY        1
# 4     AYI        1

# %%
headers = ['symbol', 'current_price', 'pe_ratio', 'eps_ratio', 'market_cap', 'day_change', 'week_change', 'half_year_change', 
            'year_change', 'free_cach_flow_change_1y', 'free_cach_flow_change_2y', 'free_cach_flow_change_3y', 
            'revenue_change_1y', 'revenue_change_2y', 'revenue_change_3y']

data = pd.read_csv('test.csv', names = headers)# Connect to MongoDB
data.head()
# Out:
#   symbol  current_price  pe_ratio  eps_ratio  market_cap  day_change  \
# 0     BE          20.51      -1.0      -1.63       4.460        4.92
# 1   FIVN          72.54      -1.0      -1.34       5.372        5.79
# 2     BB           4.61      -1.0      -0.57       2.775       15.46
# 3   TWKS           7.23      -1.0      -0.33       2.289        5.09
# 4      W          34.76      -1.0     -12.44       3.880        7.11
#
#    week_change  half_year_change  year_change  free_cach_flow_change_1y  \
# 0        12.20             14.39       -16.42                    179.25
# 1        15.45             -5.76       -37.73                   -338.10
# 2        20.05              0.66       -31.70                    323.88
# 3         1.83            -24.77       -65.46                    -29.65
# 4         1.52             13.48       -68.72                   -970.77
#
#    free_cach_flow_change_2y  free_cach_flow_change_3y  revenue_change_1y  \
# ...

# %%
data['price_after'] = 0
data.head()
# Out:
#   symbol  current_price  pe_ratio  eps_ratio  market_cap  day_change  \
# 0     BE          20.51      -1.0      -1.63       4.460        4.92
# 1   FIVN          72.54      -1.0      -1.34       5.372        5.79
# 2     BB           4.61      -1.0      -0.57       2.775       15.46
# 3   TWKS           7.23      -1.0      -0.33       2.289        5.09
# 4      W          34.76      -1.0     -12.44       3.880        7.11
#
#    week_change  half_year_change  year_change  free_cach_flow_change_1y  \
# 0        12.20             14.39       -16.42                    179.25
# 1        15.45             -5.76       -37.73                   -338.10
# 2        20.05              0.66       -31.70                    323.88
# 3         1.83            -24.77       -65.46                    -29.65
# 4         1.52             13.48       -68.72                   -970.77
#
#    free_cach_flow_change_2y  free_cach_flow_change_3y  revenue_change_1y  \
# ...

# %%
data.to_csv('test2.csv', index = False, mode='a', header=False)

# %%
client =  MongoClient("mongodb+srv://prosowiec:ATLASSTOCKDATA@stockdata.olon5zx.mongodb.net/?retryWrites=true&w=majority")
db = client['stockdata']
collection = db['stonks']

# %%
data = pd.DataFrame(list(collection.find({'price_after': 0})))

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res_df = pd.DataFrame()
for i in data.index:
    if pd.isnull(data.loc[i, 'price_after']):
        res_df = pd.concat([res_df,data.loc[i]],ignore_index = True, axis=1)

# %%
res_df = res_df.T
res_df
# Out:
#                           _id symbol current_price pe_ratio eps_ratio  \
# 0    64284d399ead2017875f80df     KC          8.95     -1.0     -1.57
# 1    64284d399ead2017875f80e0    RPD          45.4     -1.0     -2.14
# 2    64284d399ead2017875f80e1    CAR         196.1     3.47     56.45
# 3    64284d399ead2017875f80e2      S          16.2     -1.0     -1.36
# 4    64284d399ead2017875f80e3   NVCR         60.83     -1.0     -0.87
# ..                        ...    ...           ...      ...       ...
# 112  64284d399ead2017875f814f  WXXWY         12.36    47.54      0.26
# 113  64284d399ead2017875f8150   GNRC        108.88    19.62      5.55
# 114  64284d399ead2017875f8151   BILI         23.79     -1.0     -3.12
# 115  64284d399ead2017875f8152  NPNYY          4.65     1.24      3.74
# 116  64284d399ead2017875f8153  GNZUF          0.61     4.36      0.14
#
#     market_cap day_change week_change half_year_change year_change  \
# ...

# %%
import os
print(os.environ.get('con_string'))
# Out:
# None
